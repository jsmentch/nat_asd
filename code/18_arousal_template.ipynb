# %%
import nilearn as nl
import numpy as np
import nibabel as nb
import nilearn.plotting as nlplt
import nilearn

# %%
with open('pilots_ru_dm_list.txt', 'r') as file:
    sub_list = file.readlines()
good_subjects_list = [line.strip() for line in sub_list]

# %%
good_subjects_list[0]
# Out:
# 'NDARWW005GCU'

# %%
arousal_full=nb.load('../data/full_template.nii')

# %%
arousal_full.get_fdata().shape
# Out:
# (91, 109, 91)

# %%
arousal_full=nb.load('../data/one_percent_template_MNI152NLin2009cAsym.nii')

# %%
arousal_full.get_fdata().shape
# Out:
# (97, 115, 97)

# %%
templateflow='/om2/user/jsmentch/data/datalad/templateflow/tpl-MNI152NLin2009cAsym/tpl-MNI152NLin2009cAsym_res-02_desc-brain_T1w.nii.gz'

templateflow=nb.load('/om2/user/jsmentch/data/datalad/templateflow/tpl-MNI152NLin2009cAsym/tpl-MNI152NLin2009cAsym_res-02_desc-brain_T1w.nii.gz')
templateflow.get_fdata().shape
# Out:
# (97, 115, 97)

# %%
sub=good_subjects_list[0]
sub_file=f'/nese/mit/group/sig/projects/hbn/hbn_bids/derivatives/fmriprep_23.2.0/sub-{sub}/ses-HBNsiteRU/func/sub-{sub}_ses-HBNsiteRU_task-movieDM_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz'
sub_func=nb.load(sub_file)
sub_func=sub_func.get_fdata()

# %%
from nilearn.image.image import mean_img
mean_img_sub = mean_img(sub_file)

# %%
from nilearn.plotting import plot_epi, show
plot_epi(mean_img_sub, colorbar=True, cbar_tick_format="%i")
show()  # Display the plot

# %%
sub_func.shape
# Out:
# (64, 79, 68, 750)

# %%
nlplt.plot_stat_map(arousal_full,bg_img=templateflow)

# %%
nlplt.plot_stat_map(arousal_full)

# %%
templateflow='/om2/user/jsmentch/data/datalad/templateflow/tpl-MNI152NLin2009cAsym/tpl-MNI152NLin2009cAsym_res-02_desc-brain_T1w.nii.gz'
nlplt.plot_anat(templateflow,cut_coords=(-1,-84,7))

# %%
result_img = nilearn.image.math_img("img1 * img2",
                      img1=sub_file, img2=arousal_full)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 result_img = nilearn.image.math_img("img1 * img2",
#       2                       img1=sub_file, img2=arousal_full)
#
# File /om2/user/jsmentch/anaconda/envs/hbn_asd/lib/python3.11/site-packages/nilearn/image/image.py:1066, in math_img(formula, copy_header_from, **imgs)
#    1064 try:
#    1065     niimgs = [check_niimg(image) for image in imgs.values()]
# -> 1066     check_same_fov(*niimgs, raise_error=True)
#    1067 except Exception as exc:
#    1068     exc.args = (
#    1069         "Input images cannot be compared, "
#    1070         f"you provided '{imgs.values()}',",
#    1071     ) + exc.args
#
# File /om2/user/jsmentch/anaconda/envs/hbn_asd/lib/python3.11/site-packages/nilearn/_utils/niimg_conversions.py:64, in check_same_fov(*args, **kwargs)
# ...
